# %% [markdown]
# # Using The Odds API for Arbitrage Opportunities

# %%
import requests
import pandas as pd
import numpy as np

API_KEY = '0ccdd8b5c3672b187c7c30fcad24a694'

# %%
# defining necessary params for Odds API

SPORT = 'basketball_nba'
REGIONS = 'us'
MARKETS = 'h2h' # two outcomes
ODDS_FORMAT = 'decimal'
DATE_FORMAT = 'iso'
BET_SIZE = 10 # defines monetary amount willing to spend

response = requests.get(f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds', 
                       params = {
                           'api_key': API_KEY,
                           'regions': REGIONS,
                           'markets': MARKETS,
                           'oddsFormat': ODDS_FORMAT,
                           'dateFormat': DATE_FORMAT,
                           }
                       ).json()

print(response)
# Out:
# [{'id': 'bcd6fb33fb5797ee8e2713a11ce3a947', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-05-01T23:30:00Z', 'home_team': 'Boston Celtics', 'away_team': 'Philadelphia 76ers', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-05-01T19:51:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:45Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.9}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-05-01T19:51:57Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:57Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.85}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.75}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-05-01T19:53:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:44Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-05-01T19:53:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:52Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-05-01T19:52:04Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:52:04Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-05-01T19:54:14Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:14Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-05-01T19:54:14Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:14Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-05-01T19:54:29Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:29Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.21}, {'name': 'Philadelphia 76ers', 'price': 4.84}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-05-01T19:50:37Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:37Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.21}, {'name': 'Philadelphia 76ers', 'price': 4.85}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-05-01T19:53:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:28Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.18}, {'name': 'Philadelphia 76ers', 'price': 4.33}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-05-01T19:54:21Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:21Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-05-01T19:51:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:25Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.5}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.75}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-05-01T19:53:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:51Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2 ...

# %%
# parsing and storing individual sports events

class Event:
    def __init__(self, data):
        self.data = data
        self.key = data['sport_key']
        self.id = data['id']
        
    def find_odds(self):
        outcomes = len(self.data['bookmakers'][0]['markets'][0]['outcomes'])
        self.outcomes = outcomes
        
        top_odds = [[None, None, float('-inf')] for _ in range(outcomes)]
        bookmakers = event.data['bookmakers']
        for i, bookmaker in enumerate(bookmakers):
            for opportunity in range(outcomes):
                bookmaker_current_odds = float(bookmaker['markets'][0]['outcomes'][opportunity]['price'])
                current_top_odds = top_odds[opportunity][2]
                
                if bookmaker_current_odds > current_top_odds:
                    top_odds[opportunity][0] = bookmaker['title']
                    top_odds[opportunity][1] = bookmaker['markets'][0]['outcomes'][opportunity]['name']
                    top_odds[opportunity][2] = bookmaker_current_odds
                    
        self.top_odds = top_odds
        return top_odds
    
    def find_arbitrage(self):
        percent = 0
        for odds in self.top_odds:
            percent += (1.0 / odds[2])
            
        self.percent = percent
        self.earnings = (10 / percent) - 10 # 10 is the number of bets, can change
        
        if percent < 1:
            print("Arbitrage Opportunity")
            return True
        
        print("No Arbitrage Opportunity")
        return False
    
    # have to convert from decimal to american because odds-api doesn't support this
    def convert_items(self):
        top_odds = self.top_odds
        for odds in top_odds:
            val = odds[2]
            if val >= 2:
                return_val = (val - 1) * 100
            elif val < 2:
                return_val = -100 / (val - 1)
            odds[2] = round(return_val, 2)
            
        return top_odds
    
    def calculate_arbitrage(self):
        top_odds = self.top_odds
        arr = []
        for opportunity in range(self.outcomes):
            i_percent = 1 / self.top_odds[opportunity][2]
            bet_amount = (10 * i_percent) / self.percent
            arr.append(round(bet_amount, 2))
            
        self.arr = arr
        return arr
    
    # convert to american from decimal?

# %%
events = []
for data in response:
    events.append(Event(data))
    print(data)
    print()
    
arb_events = []
for event in events:
    top_odds = event.find_odds()
    if event.find_arbitrage():
        arb_events.append(event)
        
for event in arb_events:
    event.calculate_arbitrage()
    event.convert_items()
# Out:
# {'id': 'bcd6fb33fb5797ee8e2713a11ce3a947', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-05-01T23:30:00Z', 'home_team': 'Boston Celtics', 'away_team': 'Philadelphia 76ers', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-05-01T19:51:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:45Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.9}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-05-01T19:51:57Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:57Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.85}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.2}, {'name': 'Philadelphia 76ers', 'price': 4.75}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-05-01T19:53:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:44Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-05-01T19:53:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:52Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-05-01T19:52:04Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:52:04Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-05-01T19:54:14Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:14Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-05-01T19:54:14Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:14Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.4}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-05-01T19:54:29Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:29Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.21}, {'name': 'Philadelphia 76ers', 'price': 4.84}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-05-01T19:50:37Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:37Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.21}, {'name': 'Philadelphia 76ers', 'price': 4.85}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-05-01T19:53:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:28Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.18}, {'name': 'Philadelphia 76ers', 'price': 4.33}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-05-01T19:54:21Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:21Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-05-01T19:51:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:25Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.5}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.22}, {'name': 'Philadelphia 76ers', 'price': 4.75}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-05-01T19:53:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:51Z', 'outcomes': [{'name': 'Boston Celtics', 'price': 1.21 ...
#
# {'id': 'e1edac94b261c7eceeb6b94843e847b2', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-05-02T02:00:00Z', 'home_team': 'Denver Nuggets', 'away_team': 'Phoenix Suns', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-05-01T19:51:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:45Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.59}, {'name': 'Phoenix Suns', 'price': 2.45}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-05-01T19:51:57Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:57Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.57}, {'name': 'Phoenix Suns', 'price': 2.48}]}]}, {'key': 'circasports', 'title': 'Circa Sports', 'last_update': '2023-05-01T19:54:08Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:08Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.56}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-05-01T19:50:37Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:37Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.59}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-05-01T19:53:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:51Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.56}, {'name': 'Phoenix Suns', 'price': 2.52}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-05-01T19:54:29Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:29Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.57}, {'name': 'Phoenix Suns', 'price': 2.54}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.57}, {'name': 'Phoenix Suns', 'price': 2.45}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-05-01T19:51:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:25Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.59}, {'name': 'Phoenix Suns', 'price': 2.4}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-05-01T19:53:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:19Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.57}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-05-01T19:53:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:28Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.5}, {'name': 'Phoenix Suns', 'price': 2.4}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-05-01T19:54:21Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:21Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.59}, {'name': 'Phoenix Suns', 'price': 2.38}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.59}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2023-05-01T19:50:13Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:13Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.56}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-05-01T19:53:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:52Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.56}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-05-01T19:54:14Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:14Z', 'outcomes': [{'name': 'Denver Nuggets', 'price': 1.56}, {'name': 'Phoenix Suns', 'price': 2.5}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_upd ...
#
# {'id': 'cfeb4540fbdf359624f5035f360577e1', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-05-02T23:30:00Z', 'home_team': 'New York Knicks', 'away_team': 'Miami Heat', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-05-01T19:51:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:45Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.35}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-05-01T19:51:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:25Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.4}, {'name': 'New York Knicks', 'price': 1.33}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-05-01T19:51:57Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:57Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.35}, {'name': 'New York Knicks', 'price': 1.34}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.25}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-05-01T19:53:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:51Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.4}, {'name': 'New York Knicks', 'price': 1.33}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-05-01T19:50:37Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:37Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.35}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-05-01T19:54:29Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:29Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.35}, {'name': 'New York Knicks', 'price': 1.35}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-05-01T19:53:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:19Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.35}, {'name': 'New York Knicks', 'price': 1.35}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2023-05-01T19:50:13Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:13Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.4}, {'name': 'New York Knicks', 'price': 1.33}]}]}, {'key': 'circasports', 'title': 'Circa Sports', 'last_update': '2023-05-01T19:54:08Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:08Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.13}, {'name': 'New York Knicks', 'price': 1.39}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-05-01T19:53:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:28Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.05}, {'name': 'New York Knicks', 'price': 1.33}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-05-01T19:54:21Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:21Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.4}, {'name': 'New York Knicks', 'price': 1.33}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.4}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-05-01T19:53:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:44Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.25}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-05-01T19:53:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:52Z', 'outcomes': [{'name': 'Miami Heat', 'price': 3.25}, {'name': 'New York Knicks', 'price': 1.36}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '20 ...
#
# {'id': 'c7fbe81ad1feafeebb4baef0fc02fcf4', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2023-05-03T02:00:00Z', 'home_team': 'Golden State Warriors', 'away_team': 'Los Angeles Lakers', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-05-01T19:51:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:45Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.53}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-05-01T19:50:37Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:37Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.56}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-05-01T19:54:29Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:29Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.55}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-05-01T19:51:57Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:57Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.51}, {'name': 'Los Angeles Lakers', 'price': 2.66}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-05-01T19:53:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:51Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.56}, {'name': 'Los Angeles Lakers', 'price': 2.52}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-05-01T19:53:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:19Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.54}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2023-05-01T19:50:13Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:50:13Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.51}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.53}, {'name': 'Los Angeles Lakers', 'price': 2.55}]}]}, {'key': 'circasports', 'title': 'Circa Sports', 'last_update': '2023-05-01T19:54:08Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:08Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.55}, {'name': 'Los Angeles Lakers', 'price': 2.53}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-05-01T19:53:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:28Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.5}, {'name': 'Los Angeles Lakers', 'price': 2.4}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-05-01T19:54:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:19Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.54}, {'name': 'Los Angeles Lakers', 'price': 2.65}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-05-01T19:54:21Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:54:21Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.54}, {'name': 'Los Angeles Lakers', 'price': 2.49}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-05-01T19:51:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:51:25Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.53}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-05-01T19:53:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-05-01T19:53:44Z', 'outcomes': [{'name': 'Golden State Warriors', 'price': 1.53}, {'name': 'Los Angeles Lakers', 'price': 2.6}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-05-01T19:53:52Z', 'markets': [{'key' ...
#
# No Arbitrage Opportunity
# No Arbitrage Opportunity
# No Arbitrage Opportunity
# No Arbitrage Opportunity
